# %%
print("Atribuição de valores")
# Out:
# Atribuição de valores

# %%
idade = 30
idade
# Out:
# 30

# %%
print("Verificar tipo da variavel")
type(idade)
# Out:
# Verificar tipo da variavel
# int

# %%
print("Atribuições com operações")
idade = 30
idade += 1
idade
# Out:
# Atribuições com operações
# 31

# %%
print("Atribuições múltiplas")
idade,altura = 30,1.78
idade
altura
# Out:
# Atribuições múltiplas
# 1.78
